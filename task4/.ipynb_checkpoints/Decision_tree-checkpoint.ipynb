# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import export_graphviz
import matplotlib.pyplot as plt

# %%
from IPython.display import Image
import pydot

# %%
data=pd.read_csv("Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
pd.get_dummies(data["Species"])
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %% [markdown]
# Converting our target value into different classes as 0 , 1 and 2

# %%
data["Species"]=LabelEncoder().fit_transform(data["Species"])

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %% [markdown]
# Dependent and independent features

# %%
X=data.iloc[:,[1,2,3,4]]
y=data.iloc[:,5]

# %% [markdown]
# Divide our data by using train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.33, random_state=42)

# %% [markdown]
# Train our model

# %%
model=DecisionTreeClassifier(max_depth=2,random_state=0)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
model.predict(X_test)
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 1, 2, 1, 2])

# %%
tree.plot_tree(model)
# Out:
# [Text(133.92000000000002, 181.2, 'X[3] <= 0.8\ngini = 0.666\nsamples = 100\nvalue = [31, 35, 34]'),
#  Text(66.96000000000001, 108.72, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]'),
#  Text(200.88000000000002, 108.72, 'X[3] <= 1.75\ngini = 0.5\nsamples = 69\nvalue = [0, 35, 34]'),
#  Text(133.92000000000002, 36.23999999999998, 'gini = 0.188\nsamples = 38\nvalue = [0, 34, 4]'),
#  Text(267.84000000000003, 36.23999999999998, 'gini = 0.062\nsamples = 31\nvalue = [0, 1, 30]')]

# %%
feature_name=["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]
class_name=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

fig,ax1=plt.subplots(nrows=1,ncols=1,figsize=(6,3),dpi=300)

tree.plot_tree(model,feature_names=feature_name,class_names=class_name,filled=True,
              max_depth=2,rounded=True)

##Figure size (figsize) determines the size of the figure in inches. 
#This gives the amount of space the axes (and other elements) have inside the figure. 
#The default figure size is (6.4, 4.8) inches in matplotlib 2. 
#A larger figure size will allow for longer texts, more axes or more ticklabels to be shown.

##Dots per inches (dpi) determines how many pixels the figure comprises. 
#The default dpi in matplotlib is 100.
# Out:
# [Text(558.0, 566.25, 'PetalWidthCm <= 0.8\ngini = 0.666\nsamples = 100\nvalue = [31, 35, 34]\nclass = Iris-versicolor'),
#  Text(279.0, 339.75, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]\nclass = Iris-setosa'),
#  Text(837.0, 339.75, 'PetalWidthCm <= 1.75\ngini = 0.5\nsamples = 69\nvalue = [0, 35, 34]\nclass = Iris-versicolor'),
#  Text(558.0, 113.25, 'gini = 0.188\nsamples = 38\nvalue = [0, 34, 4]\nclass = Iris-versicolor'),
#  Text(1116.0, 113.25, 'gini = 0.062\nsamples = 31\nvalue = [0, 1, 30]\nclass = Iris-virginica')]

# %% [markdown]
# Generate the dot file of our tree and exports as a file name tree.dot

# %%
tree.export_graphviz(model,out_file="tree.dot",class_names=class_name,
                     feature_names=feature_name,filled=True)

# %% [markdown]
# Convert our dot file into png file

# %%
! dot -Tpng tree.dot -o sample.png

# %% [markdown]
# conda install -c anaconda graphviz

# %% [markdown]
# ### very important

# %% [markdown]
# Figure size (figsize) determines the size of the figure in inches. This gives the amount of space the axes (and other elements) have inside the figure. The default figure size is (6.4, 4.8) inches in matplotlib 2. A larger figure size will allow for longer texts, more axes or more ticklabels to be shown.
#
# Dots per inches (dpi) determines how many pixels the figure comprises. The default dpi in matplotlib is 100. A figure of figsize=(w,h) will have
#
# px, py = w*dpi, h*dpi  # pixels
#
# e.g.
#
#  6.4 inches * 100 dpi = 640 pixels
#
# So in order to obtain a figure with a pixel size of e.g. (1200,600) you may chose several combinations of figure size and dpi, e.g.
#
# figsize=(15,7.5), dpi= 80
#
# figsize=(12,6)  , dpi=100
#
# figsize=( 8,4)  , dpi=150
#
# figsize=( 6,3)  , dpi=200
#
# etc.
